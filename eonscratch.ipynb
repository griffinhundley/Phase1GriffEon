# %%
'hello world'

# %%
import pandas as pd

import numpy as np

# %%
df_movies = pd.read_csv('data/tmdb.movies.csv')

# %%
df_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df_movies.drop(columns = {'Unnamed: 0', 'id', 'original_language', 'original_title'}, inplace = True)

# %%
df_movies.head()
# Out:
#              genre_ids  popularity release_date  \
# 0      [12, 14, 10751]      33.533   2010-11-19
# 1  [14, 12, 16, 10751]      28.734   2010-03-26
# 2        [12, 28, 878]      28.515   2010-05-07
# 3      [16, 35, 10751]      28.005   1995-11-22
# 4        [28, 878, 12]      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df_movies = df_movies.set_index('title')

# %%
df_movies['release_date'] = pd.to_datetime(df_movies['release_date'])

# %%
df_movies.sort_values(by = 'release_date', ascending = False)
# Out:
#                                                       genre_ids  popularity  \
# title
# Murdery Christmas                  [27, 80, 80, 80, 80, 80, 80]       0.840
# Ophelia                                             [10749, 18]       8.715
# This Changes Everything                                    [99]       3.955
# Trial by Fire                                              [18]       4.480
# All Creatures Here Below                                   [18]       8.316
# ...                                                         ...         ...
# The Best Years of Our Lives                     [18, 36, 10749]       9.647
# How Walt Disney Cartoons Are Made                            []       0.600
# Le Bonheur                                      [35, 18, 10749]       1.653
# The Vampire Bat                                        [27, 53]       2.292
# All Quiet on the Western Front                      [18, 10752]       9.583
#
#                                   release_date  vote_average  vote_count
# title
# Murdery Christmas                   2020-12-25           0.0           1
# Ophelia                             2019-06-28           0.0           4
# This Changes Everything             2019-06-28           0.0           1
# Trial by Fire                       2019-05-17           7.0           3
# All Creatures Here Below            2019-05-17           5.0           5
# ...                                        ...           ...         ...
# The Best Years of Our Lives         1946-12-25           7.8         243
# How Walt Disney Cartoons Are Made   1939-01-19           7.3           3
# Le Bonheur                          1936-02-27           8.7           3
# The Vampire Bat                     1933-01-21           5.6          23
# All Quiet on the Western Front      1930-04-29           7.8         299
#
# [26517 rows x 5 columns]

# %%
df_movies.head()
#df_movies.shape
# Out:
#                                                         genre_ids  popularity  \
# title
# Harry Potter and the Deathly Hallows: Part 1      [12, 14, 10751]      33.533
# How to Train Your Dragon                      [14, 12, 16, 10751]      28.734
# Iron Man 2                                          [12, 28, 878]      28.515
# Toy Story                                         [16, 35, 10751]      28.005
# Inception                                           [28, 878, 12]      27.920
#
#                                              release_date  vote_average  \
# title
# Harry Potter and the Deathly Hallows: Part 1   2010-11-19           7.7
# How to Train Your Dragon                       2010-03-26           7.7
# Iron Man 2                                     2010-05-07           6.8
# Toy Story                                      1995-11-22           7.9
# Inception                                      2010-07-16           8.3
#
#                                               vote_count
# title
# Harry Potter and the Deathly Hallows: Part 1       10788
# How to Train Your Dragon                            7610
# Iron Man 2                                         12368
# Toy Story                                          10174
# Inception                                          22186

# %%
df_budgets = pd.read_csv('data/tn.movie_budgets.csv')

# %%
df_budgets.head()
df_budgets['release_date'] = pd.to_datetime(df_budgets['release_date'])

# %%
df_budgets.head()
# Out:
#   release_date                                        movie     budget  \
# 0   2009-12-18                                       Avatar  425000000
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides  410600000
# 2   2019-06-07                                 Dark Phoenix  350000000
# 3   2015-05-01                      Avengers: Age of Ultron  330600000
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi  317000000
#
#       wwgross
# 0  2776345279
# 1  1045663875
# 2   149762350
# 3  1403013963
# 4  1316721747

# %%
# df_budgets['release_date'] = pd.to_datetime(df_budgets['release_date'])

df_budgets = df_budgets.rename(columns = {'production_budget':'budget'})
df_budgets = df_budgets.rename(columns = {'worldwide_gross':'wwgross'})

# df_budgets['budget'] = df_budgets['budget'].str.replace(',', '')
# df_budgets['budget'] = df_budgets['budget'].str.replace('$' ,'')
# df_budgets['budget'] = df_budgets['budget'].astype(float)

df_budgets['budget'] = df_budgets['budget'].apply(lambda x: x.replace('$', '').replace(',',''))


# df_budgets['wwgross'] = df_budgets['wwgross'].str.replace('$','')
# df_budgets['wwgross'] = df_budgets['wwgross'].str.replace(',','')
# df_budgets['wwgross'] = df_budgets['wwgross'].astype(float)

df_budgets['wwgross'] = df_budgets['wwgross'].apply(lambda x:  x.replace('$','').replace(',',''))



#df_budgets = df_budgets.drop(columns = {'id', 'domestic_gross'})
#df_budgets.head()

#print(type(df_budgets['wwgross']), type(df_budgets['budget']))

# %%
df_budgets = df_budgets.sort_values(by = 'release_date', ascending = False)

# %%
import datetime as dt
type(df_budgets['release_date'].)

# df['Date'] = pd.to_datetime(df['Date'])
# include = df[df['Date'].dt.year == year]
# Out:
# pandas.core.series.Series

# %%
later_2010
# Out:
#      release_date                           movie     budget   wwgross
# 194    2020-12-31                        Moonfall  150000000         0
# 1205   2020-12-31          Hannibal the Conqueror   50000000         0
# 535    2020-02-21                Call of the Wild   82000000         0
# 480    2019-12-31                Army of the Dead   90000000         0
# 3515   2019-12-31                             Eli   11000000         0
# ...           ...                             ...        ...       ...
# 2233   1970-09-23                Tora, Tora, Tora   25000000  29548291
# 2798   1970-06-24                        Catch-22   18000000  24911670
# 4682   1970-05-26  Beneath the Planet of the Apes    3000000  17489009
# 4580   1970-05-13       The Ballad of Cable Hogue    3716946   5000000
# 5407   1970-03-26                       Woodstock     600000  34505110
#
# [5616 rows x 4 columns]

# %%
df_budgets.tail()
# Out:
#      release_date                           movie  budget   wwgross
# 5606   1925-11-19                  The Big Parade  245000  22000000
# 5683   1920-09-17  Over the Hill to the Poorhouse  100000   3000000
# 5614   1916-12-24    20,000 Leagues Under the Sea  200000   8000000
# 5523   1916-09-05                     Intolerance  385907         0
# 5677   1915-02-08           The Birth of a Nation  110000  11000000

# %%
df_budgets['profit_index'] = df_budgets['wwgross']/df_budgets['budget']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e1147cd59869> in <module>()
# ----> 1 df_budgets['profit_index'] = df_budgets['wwgross']/df_budgets['budget']
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# /Users/eonjamesslemp/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     445         if mask.any():
#     446             with np.errstate(all="ignore"):
# --> 447                 result[mask] = op(xrav[mask], com.values_from_object(yrav[mask]))
#     448
#     449     else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
df_budgets = df_budgets.rename(columns = {'movie':'title'})

# %%
df_budgets.set_index('title')
# Out:
#                                              release_date       budget  \
# title
# Avatar                                       Dec 18, 2009  425000000.0
# Pirates of the Caribbean: On Stranger Tides  May 20, 2011  410600000.0
# Dark Phoenix                                  Jun 7, 2019  350000000.0
# Avengers: Age of Ultron                       May 1, 2015  330600000.0
# Star Wars Ep. VIII: The Last Jedi            Dec 15, 2017  317000000.0
# ...                                                   ...          ...
# Red 11                                       Dec 31, 2018       7000.0
# Following                                     Apr 2, 1999       6000.0
# Return to the Land of Wonders                Jul 13, 2005       5000.0
# A Plague So Pleasant                         Sep 29, 2015       1400.0
# My Date With Drew                             Aug 5, 2005       1100.0
#
#                                                   wwgross  profit_index
# title
# Avatar                                       2.776345e+09      6.532577
# Pirates of the Caribbean: On Stranger Tides  1.045664e+09      2.546673
# Dark Phoenix                                 1.497624e+08      0.427892
# Avengers: Age of Ultron                      1.403014e+09      4.243841
# Star Wars Ep. VIII: The Last Jedi            1.316722e+09      4.153696
# ...                                                   ...           ...
# Red 11                                       0.000000e+00      0.000000
# Following                                    2.404950e+05     40.082500
# Return to the Land of Wonders                1.338000e+03      0.267600
# A Plague So Pleasant                         0.000000e+00      0.000000
# My Date With Drew                            1.810410e+05    164.582727
#
# [5782 rows x 4 columns]

# %%
df_budgets['release_date'] = pd.to_datetime(df_budgets['release_date'])

# %%
df_budgets.head()
# Out:
#   release_date                                        title       budget  \
# 0   2009-12-18                                       Avatar  425000000.0
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides  410600000.0
# 2   2019-06-07                                 Dark Phoenix  350000000.0
# 3   2015-05-01                      Avengers: Age of Ultron  330600000.0
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi  317000000.0
#
#         wwgross  profit_index
# 0  2.776345e+09      6.532577
# 1  1.045664e+09      2.546673
# 2  1.497624e+08      0.427892
# 3  1.403014e+09      4.243841
# 4  1.316722e+09      4.153696

# %%
df_budgets.shape
# Out:
# (5782, 5)

# %%
df_movies.head()
# Out:
#                                                         genre_ids  popularity  \
# title
# Harry Potter and the Deathly Hallows: Part 1      [12, 14, 10751]      33.533
# How to Train Your Dragon                      [14, 12, 16, 10751]      28.734
# Iron Man 2                                          [12, 28, 878]      28.515
# Toy Story                                         [16, 35, 10751]      28.005
# Inception                                           [28, 878, 12]      27.920
#
#                                              release_date  vote_average  \
# title
# Harry Potter and the Deathly Hallows: Part 1   2010-11-19           7.7
# How to Train Your Dragon                       2010-03-26           7.7
# Iron Man 2                                     2010-05-07           6.8
# Toy Story                                      1995-11-22           7.9
# Inception                                      2010-07-16           8.3
#
#                                               vote_count
# title
# Harry Potter and the Deathly Hallows: Part 1       10788
# How to Train Your Dragon                            7610
# Iron Man 2                                         12368
# Toy Story                                          10174
# Inception                                          22186

# %%
df_movies.shape
# Out:
# (26517, 10)

# %%
df_movies.shape

# %%
movies_pkle = pd.merge(df_budgets, df_movies, how = 'inner', on ='title')
movies_pkle.shape
# Out:
# (2385, 14)

# %%
movies_pkle.head(20)
# Out:
#    release_date_x                                             title  \
# 0      2009-12-18                                            Avatar
# 1      2011-05-20       Pirates of the Caribbean: On Stranger Tides
# 2      2015-05-01                           Avengers: Age of Ultron
# 3      2018-04-27                            Avengers: Infinity War
# 4      2017-11-17                                    Justice League
# 5      2017-11-17                                    Justice League
# 6      2015-11-06                                           Spectre
# 7      2015-11-06                                           Spectre
# 8      2012-07-20                             The Dark Knight Rises
# 9      2018-05-25                           Solo: A Star Wars Story
# 10     2013-07-02                                   The Lone Ranger
# 11     2012-03-09                                       John Carter
# 12     2010-11-24                                           Tangled
# 13     2016-05-06                        Captain America: Civil War
# 14     2016-03-25                Batman v Superman: Dawn of Justice
# 15     2012-12-14                 The Hobbit: An Unexpected Journey
# 16     2013-12-13               The Hobbit: The Desolation of Smaug
# 17     2014-12-17         The Hobbit: The Battle of the Five Armies
# 18     2017-04-14                           The Fate of the Furious
# 19     2017-05-26  Pirates of the Caribbean: Dead Men Tell No Tales
#
#          budget       wwgross  profit_index  Unnamed: 0          genre_ids  \
# 0   425000000.0  2.776345e+09      6.532577           6  [28, 12, 14, 878]
# 1   410600000.0  1.045664e+09      2.546673        2470       [12, 28, 14]
# 2   330600000.0  1.403014e+09      4.243841       14169      [28, 12, 878]
# 3   300000000.0  2.048134e+09      6.827114       23811       [12, 28, 14]
# 4   300000000.0  6.559452e+08      2.186484       20623  [28, 12, 14, 878]
# 5   300000000.0  6.559452e+08      2.186484       23830  [28, 12, 14, 878]
# 6   300000000.0  8.796209e+08      2.932070       14175       [28, 12, 80]
# 7   300000000.0  8.796209e+08      2.932070       17386       [28, 12, 80]
# 8   275000000.0  1.084439e+09      3.943415        5182   [28, 80, 18, 53]
# 9   275000000.0  3.931513e+08      1.429641       23845      [28, 12, 878]
# 10  275000000.0  2.600021e+08      0.945462        7967       [28, 12, 37]
# 11  275000000.0  2.827781e+08      1.028284        5197      [28, 12, 878]
# 12  260000000.0  5.864772e+08      2.255682          13        [16, 10751]
# 13  250000000.0  1.140069e+09      4.560278       17382      [12, 28, 878]
# 14  250000000.0  8.675003e+08      3.470001       17390       [28, 12, 14]
# 15  250000000.0  1.017004e+09      4.068014        5180       [12, 14, 28]
# 16  250000000.0  9.603669e+08      3.841467        7890       [12, 14, 28]
# 17  250000000.0  9.455776e+08      3.782310       11020       [28, 12, 14]
# 18  250000000.0  1.234846e+09      4.939385       20630       [28, 80, 53]
# 19  230000000.0  7.882411e+08      3.427135       20634   [12, 28, 14, 35]
#
#         id original_language  \
# 0    19995                en
# 1     1865                en
# 2    99861                en
# 3   299536                en
# 4   141052                en
# 5   141052                en
# 6   206647                en
# 7   206647                en
# 8    49026                en
# 9   348350                en
# 10   57201                en
# 11   49529                en
# 12   38757                en
# 13  271110                en
# 14  209112                en
# 15   49051                en
# 16   57158                en
# 17  122917                en
# 18  337339                en
# 19  166426                en
#
#                                       original_title  popularity  \
# 0                                             Avatar      26.526
# 1        Pirates of the Caribbean: On Stranger Tides      30.579
# 2                            Avengers: Age of Ultron      44.383
# 3                             Avengers: Infinity War      80.773
# 4                                     Justice League      34.953
# 5                                     Justice League      34.953
# 6                                            Spectre      30.318
# 7                                            Spectre      30.318
# 8                              The Dark Knight Rises      26.220
# 9                            Solo: A Star Wars Story      29.502
# 10                                   The Lone Ranger      12.482
# 11                                       John Carter      18.549
# 12                                           Tangled      21.511
# 13                        Captain America: Civil War      39.137
# 14                Batman v Superman: Dawn of Justice      28.088
# 15                 The Hobbit: An Unexpected Journey      26.939
# 16               The Hobbit: The Desolation of Smaug      21.275
# 17         The Hobbit: The Battle of the Five Armies      53.783
# 18                           The Fate of the Furious      28.668
# 19  Pirates of the Caribbean: Dead Men Tell No Tales      28.101
#
#    release_date_y  vote_average  vote_count
# 0      2009-12-18           7.4       18676
# 1      2011-05-20           6.4        8571
# 2      2015-05-01           7.3       13457
# 3      2018-04-27           8.3       13948
# 4      2017-11-17           6.2        7510
# 5      2017-11-17           6.2        7510
# 6      2015-11-06           6.4        6719
# 7      2015-11-06           6.4        6719
# 8      2012-07-20           7.7       13933
# 9      2018-05-25           6.6        3838
# 10     2013-07-03           6.0        3789
# 11     2012-03-09           6.1        3338
# 12     2010-11-24           7.5        6407
# 13     2016-05-06           7.4       14000
# 14     2016-03-25           5.8       11991
# 15     2012-12-14           7.2       12076
# 16     2013-12-13           7.6        7739
# 17     2014-12-17           7.3        8392
# 18     2017-04-14           6.9        6335
# 19     2017-05-26           6.6        6931

# %%
df_budgets['wwgross'].dtype
# Out:
# dtype('float64')

# %%
# df_budgets = df_budgets.rename(columns = {'production_budget' : 'budget'})

# df_budgets = df_budgets.set_index('')
#df_budgets = df_budgets.set_index('')

# df_budgets.columns

# def budget_to_gross(budget, gross):
#     budget_by_gross = budget/gross
#     return budget_by_gross

# type(df_budgets['wwgross'].iloc[0])

# df_budgets['production_budget'].head()
# df_budgets['production_budget'].str.replace(',', '').str.replace('$', '')
# df_budgets['production_budget'].astype(float)

# def greater_than_300(budget):
#     T_or_F = budget > 300000000
#     return T_or_F

# # df_budgets.head()
#df_budgets['greater_than_300'] = df_budgets['budget'].apply(greater_than_300)

# df_budgets.head()

# #df_budgets['production_budget'].value_counts(normalize = False )


df_budgets['revenue_to_cost'] = df_budgets['wwgross']/df_budgets['budget']

# # print(df_budgets['production_budget'].dtype)
# # df_budgets(['production_budget']) = df_budgets['production_budget'].obj.replace(',','')
# # #  do same but attach it to the dataframe
# # df['c'] = df.apply(lambda row: row.a + row.b, axis=1)
#df_budgets.head()
# #df_budgets.info()
df_budgets.head()
